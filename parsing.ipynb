# %% [markdown]
# <a href="https://colab.research.google.com/github/komarojugnanavi79-rgb/IIY-IV-sem-FDS/blob/main/parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

json_data = [
    {
        "id": 1,
        "name":"Ravi",
        "address":{
            "city":"Bangalore",
            "state":"Karnataka"},
        "marks":
        {
            "maths":90,
            "science":85
        }
    },
       { "id": 2,
        "name":"Sam",
        "address":{
            "city":"vizag",
            "state":"Andhra "},
        "marks":
        {
            "maths":94,
            "science":88
        }
    }
]

df=pd.DataFrame(json_data)
print(df)
flat_df=pd.json_normalize(json_data)
print(flat_df)
# Out:
#    id  name                                      address  \
# 0   1  Ravi  {'city': 'Bangalore', 'state': 'Karnataka'}
# 1   2   Sam        {'city': 'vizag', 'state': 'Andhra '}
#
#                           marks
# 0  {'maths': 90, 'science': 85}
# 1  {'maths': 94, 'science': 88}
#    id  name address.city address.state  marks.maths  marks.science
# 0   1  Ravi    Bangalore     Karnataka           90             85
# 1   2   Sam        vizag       Andhra            94             88
