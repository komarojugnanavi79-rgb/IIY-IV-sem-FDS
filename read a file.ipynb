# %% [markdown]
# <a href="https://colab.research.google.com/github/komarojugnanavi79-rgb/IIY-IV-sem-FDS/blob/main/read%20a%20file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f1 = open("myfile.txt", "w")
L = ["This is Delhi \n", "This is paris \n", "This is London \n"]
f1.write("Hello \n")
f1.writelines(L)
f1.close()
f1 = open("myfile.txt", "r+")
print("Output of read():")
print(f1.read())
print()
f1.seek(0)
print("Output of readline():")
print(f1.readline())
print()
f1.seek(0)
print("Output of read(9):")
print(f1.read(9))
print()
# Out:
# Output of read():
# Hello
# This is Delhi
# This is paris
# This is London
#
#
# Output of readline():
# Hello
#
#
# Output of read(9):
# Hello
# Th
